# %%
import numpy as np # linear algebra
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
import hopsworks

# %%
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/4247
# Connected. Call `.close()` to terminate connection gracefully.

# %%
try: 
    feature_view = fs.get_feature_view(name="new_electricity_data_fv", version=1)
except:
    electricity_data_fg = fs.get_feature_group('new_electricity_data_fg', version=1)
    query = electricity_data_fg.select_all()    
    feature_view = fs.create_feature_view(name="new_electricity_data_fv",
                                        version=1,
                                        description="Read from Feature Group new_electricity_data_fg",
                                        labels=["day_ahead_price"],
                                        query=query)

# %%
electricity_data_fg.read()
# Out:
# 2023-01-13 14:58:39,081 INFO: USE `id2223_lab1_featurestore`
# 2023-01-13 14:58:39,634 INFO: SELECT `fg0`.`hydro_water_reservoir` `hydro_water_reservoir`, `fg0`.`nuclear` `nuclear`, `fg0`.`other` `other`, `fg0`.`solar` `solar`, `fg0`.`wind_onshore` `wind_onshore`, `fg0`.`datetime` `datetime`, `fg0`.`day_ahead_price` `day_ahead_price`, `fg0`.`total_load` `total_load`, `fg0`.`temperature` `temperature`
# FROM `id2223_lab1_featurestore`.`new_electricity_data_fg_1` `fg0`
# UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#       hydro_water_reservoir  nuclear  other  solar  wind_onshore  \
# 0                    1238.0   5401.0  228.0  242.0         151.0
# 1                     314.0   6336.0  195.0    0.0        1116.0
# 2                     370.0   4630.0  526.0  135.0        1034.0
# 3                    1154.0   6992.0  909.0   66.0         451.0
# 4                     362.0   5699.0  257.0  103.0         849.0
# ...                     ...      ...    ...    ...           ...
# 8797                 1104.0   5799.0  950.0    0.0         393.0
# 8798                  552.0   5796.0  585.0    0.0         871.0
# 8799                  975.0   5799.0  917.0    3.0         256.0
# 8800                  578.0   5797.0  583.0    0.0         930.0
# 8801                  713.0   5799.0  884.0    0.0         783.0
#
#            datetime  day_ahead_price  total_load  temperature
# 0     1661515200000           628.10      8442.0         22.9
# 1     1651960800000             1.64      6673.0          7.4
# 2     1641812400000            54.93      8204.0          2.0
# 3     1647154800000            75.63     10840.0          5.0
# 4     1662566400000             3.18      7351.0         17.0
# ...             ...              ...         ...          ...
# 8797  1672675200000           170.00     12106.0          6.3
# 8798  1672628400000            50.08      9256.0          7.6
# 8799  1672653600000           143.35     11828.0          7.0
# 8800  1672617600000            51.67      9491.0          7.5
# 8801  1672696800000           118.06     10266.0          4.8
#
# [8802 rows x 9 columns]

# %%
# query_show = electricity_data_fg.show(5)
# col_names = query_show.columns

# %%
version, job = feature_view.create_training_data(
    description = 'new electricity price pred train data',
    data_format = 'csv',
    write_options = {"wait_for_job": True}
) # By default, it is materialised to HopsFS
print(job.id)
# Out:
# Training dataset job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/4247/jobs/named/new_electricity_data_fv_1_1_create_fv_td_13012023135944/executions
# 17073
# VersionWarning: Incremented version to `1`.

# %%
# train_data = feature_view.get_training_data(training_dataset_version=1)[0]
# Out:
#       hydro_water_reservoir  nuclear  other  solar  wind_onshore  \
# 0                    1238.0   5401.0  228.0  242.0         151.0
# 1                     314.0   6336.0  195.0    0.0        1116.0
# 2                     370.0   4630.0  526.0  135.0        1034.0
# 3                    1154.0   6992.0  909.0   66.0         451.0
# 4                     362.0   5699.0  257.0  103.0         849.0
# ...                     ...      ...    ...    ...           ...
# 8797                 1104.0   5799.0  950.0    0.0         393.0
# 8798                  552.0   5796.0  585.0    0.0         871.0
# 8799                  975.0   5799.0  917.0    3.0         256.0
# 8800                  578.0   5797.0  583.0    0.0         930.0
# 8801                  713.0   5799.0  884.0    0.0         783.0
#
#            datetime  total_load  temperature
# 0     1661515200000      8442.0         22.9
# 1     1651960800000      6673.0          7.4
# 2     1641812400000      8204.0          2.0
# 3     1647154800000     10840.0          5.0
# 4     1662566400000      7351.0         17.0
# ...             ...         ...          ...
# 8797  1672675200000     12106.0          6.3
# 8798  1672628400000      9256.0          7.6
# 8799  1672653600000     11828.0          7.0
# 8800  1672617600000      9491.0          7.5
# 8801  1672696800000     10266.0          4.8
#
# [8802 rows x 8 columns]

# %% [markdown]
# ### Redone with help from peer

# %%
# train_data.set_index('datetime', inplace=True)

# %%
# Split into train & test sets
train_size = int(len(train_data) * 0.80)
test_size = len(train_data) - train_size
test = train_data.iloc[train_size:,:]
train = train_data.iloc[0:train_size,:]

# %%
train.head()
# Out:
#                hydro_water_reservoir  nuclear  other  solar  wind_onshore  \
# datetime
# 1661515200000                 1238.0   5401.0  228.0  242.0         151.0
# 1651960800000                  314.0   6336.0  195.0    0.0        1116.0
# 1641812400000                  370.0   4630.0  526.0  135.0        1034.0
# 1647154800000                 1154.0   6992.0  909.0   66.0         451.0
# 1662566400000                  362.0   5699.0  257.0  103.0         849.0
#
#                day_ahead_price  total_load  temperature
# datetime
# 1661515200000           628.10      8442.0         22.9
# 1651960800000             1.64      6673.0          7.4
# 1641812400000            54.93      8204.0          2.0
# 1647154800000            75.63     10840.0          5.0
# 1662566400000             3.18      7351.0         17.0

# %%
test.head()
# Out:
#                hydro_water_reservoir  nuclear  other  solar  wind_onshore  \
# datetime
# 1657000800000                  641.0   3927.0  525.0   66.0        1385.0
# 1672092000000                  494.0   5795.0  737.0    0.0        1948.0
# 1657357200000                  823.0   4553.0  416.0  275.0         110.0
# 1663182000000                  352.0   4577.0  343.0    0.0        1069.0
# 1668340800000                 1038.0   5495.0  510.0   21.0          74.0
#
#                day_ahead_price  total_load  temperature
# datetime
# 1657000800000             5.89      7898.0         16.0
# 1672092000000            19.48      9677.0          4.5
# 1657357200000           450.38      8868.0         18.5
# 1663182000000            65.06      8587.0         14.8
# 1668340800000            38.78      9305.0         12.7

# %%
# Standard scaler for features and label

sc_x=StandardScaler()
X_scaled_train=sc_x.fit_transform(train)

# %%
sc_y=StandardScaler()
y_scaled_train=sc_y.fit_transform(train[['day_ahead_price']])

# %%
train.info()
# Out:
# 7041

# %%
step_back=24
no_records=len(train)
no_cols=8
X_train=[]
y_train=[]
for i in range(step_back,no_records):
    X_train.append(X_scaled_train[i-step_back:i])
    y_train.append(y_scaled_train[i][0])
X_train,y_train=np.array(X_train),np.array(y_train)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (7017, 24, 8)
# (7017,)

# %%
X_train_shape=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],X_train.shape[2]))
X_train_shape.shape

# %% [markdown]
# ### LSTM model

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(100, input_shape=(step_back,no_cols)))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# 2023-01-13 14:21:05.710903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-13 14:21:05.711302: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712009: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712104: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712194: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712304: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712389: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712468: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712548: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-01-13 14:21:05.712561: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-01-13 14:21:05.715740: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               43600
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 43,701
# Trainable params: 43,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_lstm.fit(X_train_shape, y_train, epochs=200, batch_size=265, verbose=1, shuffle=False)
# Out:
# Epoch 1/200
# 27/27 [==============================] - 4s 47ms/step - loss: 1.0086
# Epoch 2/200
# 27/27 [==============================] - 1s 50ms/step - loss: 1.0013
# Epoch 3/200
# 27/27 [==============================] - 1s 48ms/step - loss: 0.9995
# Epoch 4/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.9974
# Epoch 5/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.9946
# Epoch 6/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.9924
# Epoch 7/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.9916
# Epoch 8/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.9909
# Epoch 9/200
# 27/27 [==============================] - 2s 60ms/step - loss: 0.9880
# Epoch 10/200
# 27/27 [==============================] - 2s 61ms/step - loss: 0.9881
# Epoch 11/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.9831
# Epoch 12/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.9815
# Epoch 13/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.9810
# Epoch 14/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.9788
# Epoch 15/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.9734
# Epoch 16/200
# 27/27 [==============================] - 2s 85ms/step - loss: 0.9694
# Epoch 17/200
# 27/27 [==============================] - 2s 60ms/step - loss: 0.9629
# Epoch 18/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.9598
# Epoch 19/200
# 27/27 [==============================] - 2s 58ms/step - loss: 0.9527
# Epoch 20/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.9438
# Epoch 21/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.9402
# Epoch 22/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.9321
# Epoch 23/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.9217
# Epoch 24/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.9121
# Epoch 25/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.8977
# Epoch 26/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.8811
# Epoch 27/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.8685
# Epoch 28/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.8485
# Epoch 29/200
# 27/27 [==============================] - 2s 63ms/step - loss: 0.8391
# Epoch 30/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.8483
# Epoch 31/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.8323
# Epoch 32/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.8214
# Epoch 33/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.8190
# Epoch 34/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.7822
# Epoch 35/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.7557
# Epoch 36/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.7320
# Epoch 37/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.7105
# Epoch 38/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.7067
# Epoch 39/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.6996
# Epoch 40/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.7038
# Epoch 41/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.6804
# Epoch 42/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.6746
# Epoch 43/200
# 27/27 [==============================] - 2s 76ms/step - loss: 0.6526
# Epoch 44/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.6186
# Epoch 45/200
# 27/27 [==============================] - 2s 64ms/step - loss: 0.5879
# Epoch 46/200
# 27/27 [==============================] - 2s 64ms/step - loss: 0.5567
# Epoch 47/200
# 27/27 [==============================] - 2s 64ms/step - loss: 0.5488
# Epoch 48/200
# 27/27 [==============================] - 2s 64ms/step - loss: 0.5394
# Epoch 49/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5255
# Epoch 50/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.5380
# Epoch 51/200
# 27/27 [==============================] - 2s 89ms/step - loss: 0.5389
# Epoch 52/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.5298
# Epoch 53/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.5107
# Epoch 54/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.4958
# Epoch 55/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4847
# Epoch 56/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.4606
# Epoch 57/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4773
# Epoch 58/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.4471
# Epoch 59/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.4409
# Epoch 60/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.4417
# Epoch 61/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.4342
# Epoch 62/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.4383
# Epoch 63/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.4199
# Epoch 64/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.3911
# Epoch 65/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.3624
# Epoch 66/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.3426
# Epoch 67/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3317
# Epoch 68/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3318
# Epoch 69/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3173
# Epoch 70/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.3090
# Epoch 71/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3193
# Epoch 72/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.3073
# Epoch 73/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3134
# Epoch 74/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.2959
# Epoch 75/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.2950
# Epoch 76/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.3006
# Epoch 77/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.2942
# Epoch 78/200
# 27/27 [==============================] - 2s 77ms/step - loss: 0.2862
# Epoch 79/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.2963
# Epoch 80/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.2918
# Epoch 81/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.3142
# Epoch 82/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.3283
# Epoch 83/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.3269
# Epoch 84/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.3065
# Epoch 85/200
# 27/27 [==============================] - 3s 105ms/step - loss: 0.2737
# Epoch 86/200
# 27/27 [==============================] - 2s 84ms/step - loss: 0.2459
# Epoch 87/200
# 27/27 [==============================] - 2s 74ms/step - loss: 0.2405
# Epoch 88/200
# 27/27 [==============================] - 2s 87ms/step - loss: 0.2283
# Epoch 89/200
# 27/27 [==============================] - 2s 75ms/step - loss: 0.2263
# Epoch 90/200
# 27/27 [==============================] - 2s 76ms/step - loss: 0.2194
# Epoch 91/200
# 27/27 [==============================] - 2s 77ms/step - loss: 0.2149
# Epoch 92/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.2123
# Epoch 93/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.2075
# Epoch 94/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.2014
# Epoch 95/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.2047
# Epoch 96/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.2052
# Epoch 97/200
# 27/27 [==============================] - 2s 58ms/step - loss: 0.2155
# Epoch 98/200
# 27/27 [==============================] - 2s 60ms/step - loss: 0.2092
# Epoch 99/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.2094
# Epoch 100/200
# 27/27 [==============================] - 2s 56ms/step - loss: 0.2104
# Epoch 101/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.2007
# Epoch 102/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1843
# Epoch 103/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1789
# Epoch 104/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.1687
# Epoch 105/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1683
# Epoch 106/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.1690
# Epoch 107/200
# 27/27 [==============================] - 2s 75ms/step - loss: 0.1613
# Epoch 108/200
# 27/27 [==============================] - 2s 73ms/step - loss: 0.1643
# Epoch 109/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.1645
# Epoch 110/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.1548
# Epoch 111/200
# 27/27 [==============================] - 2s 63ms/step - loss: 0.1505
# Epoch 112/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.1543
# Epoch 113/200
# 27/27 [==============================] - 2s 64ms/step - loss: 0.1548
# Epoch 114/200
# 27/27 [==============================] - 2s 64ms/step - loss: 0.1460
# Epoch 115/200
# 27/27 [==============================] - 2s 88ms/step - loss: 0.1519
# Epoch 116/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.1518
# Epoch 117/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1487
# Epoch 118/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1420
# Epoch 119/200
# 27/27 [==============================] - 2s 56ms/step - loss: 0.1379
# Epoch 120/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1373
# Epoch 121/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.1336
# Epoch 122/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1293
# Epoch 123/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1240
# Epoch 124/200
# 27/27 [==============================] - 2s 57ms/step - loss: 0.1315
# Epoch 125/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1291
# Epoch 126/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1326
# Epoch 127/200
# 27/27 [==============================] - 1s 56ms/step - loss: 0.1280
# Epoch 128/200
# 27/27 [==============================] - 2s 79ms/step - loss: 0.1355
# Epoch 129/200
# 27/27 [==============================] - 2s 60ms/step - loss: 0.1361
# Epoch 130/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1416
# Epoch 131/200
# 27/27 [==============================] - 2s 58ms/step - loss: 0.1493
# Epoch 132/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.1470
# Epoch 133/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.1325
# Epoch 134/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1270
# Epoch 135/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1292
# Epoch 136/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1247
# Epoch 137/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1250
# Epoch 138/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1244
# Epoch 139/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1185
# Epoch 140/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1228
# Epoch 141/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.1235
# Epoch 142/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.1214
# Epoch 143/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.1227
# Epoch 144/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.1285
# Epoch 145/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.1241
# Epoch 146/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.1203
# Epoch 147/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.1219
# Epoch 148/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.1253
# Epoch 149/200
# 27/27 [==============================] - 2s 88ms/step - loss: 0.1268
# Epoch 150/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.1253
# Epoch 151/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1270
# Epoch 152/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1189
# Epoch 153/200
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1108
# Epoch 154/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1102
# Epoch 155/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.1090
# Epoch 156/200
# 27/27 [==============================] - 2s 57ms/step - loss: 0.1030
# Epoch 157/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0986
# Epoch 158/200
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0943
# Epoch 159/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0950
# Epoch 160/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0906
# Epoch 161/200
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0913
# Epoch 162/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0931
# Epoch 163/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0929
# Epoch 164/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0969
# Epoch 165/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.1011
# Epoch 166/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0953
# Epoch 167/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0958
# Epoch 168/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.1046
# Epoch 169/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.1016
# Epoch 170/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0984
# Epoch 171/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0947
# Epoch 172/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0916
# Epoch 173/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0858
# Epoch 174/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0794
# Epoch 175/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0809
# Epoch 176/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0820
# Epoch 177/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.0799
# Epoch 178/200
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0816
# Epoch 179/200
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0779
# Epoch 180/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.0799
# Epoch 181/200
# 27/27 [==============================] - 2s 61ms/step - loss: 0.0802
# Epoch 182/200
# 27/27 [==============================] - 2s 61ms/step - loss: 0.0795
# Epoch 183/200
# 27/27 [==============================] - 2s 62ms/step - loss: 0.0764
# Epoch 184/200
# 27/27 [==============================] - 2s 84ms/step - loss: 0.0783
# Epoch 185/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0783
# Epoch 186/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0801
# Epoch 187/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0810
# Epoch 188/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0839
# Epoch 189/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.0860
# Epoch 190/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0840
# Epoch 191/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0833
# Epoch 192/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0858
# Epoch 193/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0872
# Epoch 194/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0859
# Epoch 195/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0860
# Epoch 196/200
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0852
# Epoch 197/200
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0848
# Epoch 198/200
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0814
# Epoch 199/200
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0805
# Epoch 200/200
# 27/27 [==============================] - 1s 55ms/step - loss: 0.0772

# %%
last_24=train.iloc[-step_back:]
full_df= pd.concat((last_24,test),axis=0)
print(full_df.shape)
full_df.head()
# Out:
# (1785, 8)
#                hydro_water_reservoir  nuclear   other  solar  wind_onshore  \
# datetime
# 1664190000000                  584.0   4616.0   549.0   76.0         784.0
# 1667318400000                 1503.0   6391.0  1348.0    0.0        1670.0
# 1650513600000                  953.0   5519.0   699.0   11.0        1237.0
# 1654614000000                  651.0   6118.0   346.0  181.0        1338.0
# 1643810400000                 1539.0   6986.0  1200.0    7.0         187.0
#
#                day_ahead_price  total_load  temperature
# datetime
# 1664190000000           169.76      9341.0         13.0
# 1667318400000           173.63     14608.0         13.3
# 1650513600000            66.75      9026.0          8.9
# 1654614000000           171.79      8662.0         16.2
# 1643810400000           188.46     13944.0         -0.1

# %%
full_df=sc_x.transform(full_df)
full_df.shape
# Out:
# (1785, 8)

# %%
step_back=step_back
no_records=len(full_df)
no_cols=no_cols
X_train_shape_pred=[]
for i in range(step_back,no_records):
    X_train_shape_pred.append(full_df[i-step_back:i])
X_train_shape_pred=np.array(X_train_shape_pred)
print(X_train_shape_pred.shape)
# Out:
# (1761, 24, 8)

# %%
y_test=model_lstm.predict(X_train_shape_pred)
# Out:
# 56/56 [==============================] - 1s 6ms/step

# %%
y_final_pred=sc_y.inverse_transform(y_test)
y_final_pred
# Out:
# array([[135.74431],
#        [118.85593],
#        [160.33336],
#        ...,
#        [174.30989],
#        [237.3684 ],
#        [391.1784 ]], dtype=float32)

# %%
final_pred=pd.DataFrame(y_final_pred)
final_pred.columns=['final_pred']
final_pred.head()
# Out:
#    final_pred
# 0  135.744308
# 1  118.855927
# 2  160.333359
# 3   58.206657
# 4    8.916784

# %%
test.reset_index(inplace=True)

# %%
fully_final=pd.concat((final_pred,test),axis=1)
fully_final
# Out:
#       final_pred       datetime  hydro_water_reservoir  nuclear  other  solar  \
# 0     135.744308  1657000800000                  641.0   3927.0  525.0   66.0
# 1     118.855927  1672092000000                  494.0   5795.0  737.0    0.0
# 2     160.333359  1657357200000                  823.0   4553.0  416.0  275.0
# 3      58.206657  1663182000000                  352.0   4577.0  343.0    0.0
# 4       8.916784  1668340800000                 1038.0   5495.0  510.0   21.0
# ...          ...            ...                    ...      ...    ...    ...
# 1756   35.553268  1672675200000                 1104.0   5799.0  950.0    0.0
# 1757   37.980438  1672628400000                  552.0   5796.0  585.0    0.0
# 1758  174.309891  1672653600000                  975.0   5799.0  917.0    3.0
# 1759  237.368393  1672617600000                  578.0   5797.0  583.0    0.0
# 1760  391.178406  1672696800000                  713.0   5799.0  884.0    0.0
#
#       wind_onshore  day_ahead_price  total_load  temperature
# 0           1385.0             5.89      7898.0         16.0
# 1           1948.0            19.48      9677.0          4.5
# 2            110.0           450.38      8868.0         18.5
# 3           1069.0            65.06      8587.0         14.8
# 4             74.0            38.78      9305.0         12.7
# ...            ...              ...         ...          ...
# 1756         393.0           170.00     12106.0          6.3
# 1757         871.0            50.08      9256.0          7.6
# 1758         256.0           143.35     11828.0          7.0
# 1759         930.0            51.67      9491.0          7.5
# 1760         783.0           118.06     10266.0          4.8
#
# [1761 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
aa=[x for x in range(1761)]
plt.figure(figsize=(14,4))
plt.plot(aa, fully_final['day_ahead_price'], marker='.', label="actual")
plt.plot(aa, fully_final['final_pred'], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('Electricity Day Ahead Price [EUR/MWh]', size=15)
plt.xlabel('Time step [Hour]', size=30)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# ### Upload model to hopsworks

# %%
import hopsworks

project = hopsworks.login() 
fs = project.get_feature_store() 
mr = project.get_model_registry()

# %%
model = mr.sklearn.create_model(
    name="lstm_model",
    description="LSTM test.",
)

model.save('/content/first_model.pickle')
